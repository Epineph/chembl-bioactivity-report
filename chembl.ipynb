# %% [markdown]
# # ChEMBL Bioactivity and Predicted Pharmacokinetics
#
# This notebook launches the Voila app from `chembl_bioactivity_integrated.py`.

# %%
from chembl_bioactivity_integrated import interactive_mode

interactive_mode()
